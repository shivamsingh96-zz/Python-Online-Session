# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm      outputs
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris['outputs'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: outputs, dtype: int64

# %%
ax = iris.plot(figsize=(15,8),title = 'Iris-Dataset')

# %%
ax = iris.plot(figsize=(10,6),kind= 'scatter', title = 'Iris-Dataset', x = 'sepal length in cm', y='sepal width in cm')

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue='outputs', size = 6).map(plt.scatter,'petal length in cm','petal width in cm').add_legend()

# %%
iris['petal width in cm'].plot.hist()

# %%
iris.plot(kind = 'hist', bins = 10)

# %%
iris.iloc[0]
# Out:
# sepal length in cm            5.1
# sepal width in cm             3.5
# petal length in cm            1.4
# petal width in cm             0.2
# outputs               Iris-setosa
# Name: 0, dtype: object

# %%
iris.drop('outputs', axis = 1, inplace = True)

# %%
iris.iloc[[0,1]].plot(kind = 'bar')

# %%
titanic = pd.read_csv('titanic - Copy.csv')

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
iris['sepal width in cm'].value_counts().sort_index().plot.bar()

# %%
import plotly.express as px
grgs =
